# %%
# initialising github token as g
from github import Github

# using an access token
g = Github("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")

repo = g.get_repo("Comcast/flume2storm")
contents = repo.get_contents("")

# %%
contents
# Out:
# [ContentFile(path=".gitignore"),
#  ContentFile(path="CHANGELOG"),
#  ContentFile(path="LICENSE"),
#  ContentFile(path="NOTICE"),
#  ContentFile(path="README.md"),
#  ContentFile(path="core"),
#  ContentFile(path="dynamic-location-service"),
#  ContentFile(path="flume-spout"),
#  ContentFile(path="integration-tests"),
#  ContentFile(path="kryo-utils"),
#  ContentFile(path="kryonet-flume2storm"),
#  ContentFile(path="pom.xml"),
#  ContentFile(path="resources"),
#  ContentFile(path="static-location-service"),
#  ContentFile(path="storm-sink"),
#  ContentFile(path="test-impl"),
#  ContentFile(path="utility")]

# %%
# ignoring documentations
file_list=[]

ign_list=['.gitignore','CHANGELOG','LICENSE','NOTICE','README.md','pom.xml']

for item in contents:
    if item not in ign_list:
        if item.path not in ign_list:
            file_list.append(item)
file_list
contents = file_list

contents
# Out:
# [ContentFile(path="core"),
#  ContentFile(path="dynamic-location-service"),
#  ContentFile(path="flume-spout"),
#  ContentFile(path="integration-tests"),
#  ContentFile(path="kryo-utils"),
#  ContentFile(path="kryonet-flume2storm"),
#  ContentFile(path="resources"),
#  ContentFile(path="static-location-service"),
#  ContentFile(path="storm-sink"),
#  ContentFile(path="test-impl"),
#  ContentFile(path="utility")]

# %%
# Reading the files from each folder in the repo

files=[]
while contents:
        file_content = contents.pop(0)
        if (file_content.type== "dir"):
            contents.extend(repo.get_contents(file_content.path))
        else:
             files.append(file_content) 
             print(file_content)
#
# Out:
# ContentFile(path="core/pom.xml")
# ContentFile(path="dynamic-location-service/pom.xml")
# ContentFile(path="flume-spout/pom.xml")
# ContentFile(path="integration-tests/pom.xml")
# ContentFile(path="kryo-utils/pom.xml")
# ContentFile(path="kryonet-flume2storm/pom.xml")
# ContentFile(path="resources/assembly.xml")
# ContentFile(path="resources/license.header")
# ContentFile(path="static-location-service/pom.xml")
# ContentFile(path="storm-sink/pom.xml")
# ContentFile(path="test-impl/pom.xml")
# ContentFile(path="utility/pom.xml")
# ContentFile(path="core/src/test/resources/logback-test.xml")
# ContentFile(path="dynamic-location-service/src/test/resources/logback-test.xml")
# ContentFile(path="flume-spout/src/test/resources/logback-test.xml")
# ContentFile(path="integration-tests/src/test/resources/logback-test.xml")
# ContentFile(path="kryo-utils/src/test/resources/logback-test.xml")
# ContentFile(path="kryonet-flume2storm/src/test/resources/logback-test.xml")
# ...

# %%
# ignoring .xml and .header

import os
only_prg_files= [f for f in files if os.path.splitext(f.path)[1] != '.xml' and os.path.splitext(f.path)[1] != '.header']
files = only_prg_files
print(files)
# Out:
# [ContentFile(path="core/src/main/java/com/comcast/viper/flume2storm/F2SConfigurationException.java"), ContentFile(path="integration-tests/src/test/java/com/comcast/viper/flume2storm/IntegrationTest.java"), ContentFile(path="kryo-utils/src/main/java/com/comcast/viper/flume2storm/F2SEventSerializer.java"), ContentFile(path="kryo-utils/src/main/java/com/comcast/viper/flume2storm/KryoUtil.java"), ContentFile(path="kryo-utils/src/test/java/com/comcast/viper/flume2storm/F2SEventSerializerTest.java"), ContentFile(path="core/src/main/java/com/comcast/viper/flume2storm/event/F2SEvent.java"), ContentFile(path="core/src/main/java/com/comcast/viper/flume2storm/event/F2SEventBuilder.java"), ContentFile(path="core/src/main/java/com/comcast/viper/flume2storm/event/F2SEventComparator.java"), ContentFile(path="core/src/main/java/com/comcast/viper/flume2storm/event/F2SEventFactory.java"), ContentFile(path="core/src/main/java/com/comcast/viper/flume2storm/location/AbstractLocationService.java"), Conten
# ...

# %%
# getting every content from all files as a single list

import requests
import pandas as pd  
 
data_list = []
for i in files:
    # if file_content.encoding != 'base64':
        url = i.raw_data['download_url']
        resp = requests.get(url,timeout=10)
        data = resp.content
        data_list.append(data)
        # df = pd.DataFrame(data_list) 
    
        # df.to_csv('xPriData.csv')

# %%
# created a list of all PI's
# created a dict(PI, count) and increase count if the PI is in Data

# create a list of those 15 PI 
# get the path


pi_list = [
'account_name',
'address',
'password_reset_secret',
'ip_address',
'credit_card_num',
'first_name',
'last_name',
'date_of_birth',
'email_address',
'mac_address',
'account_identifier',
'serial_num',
'customer_account_num',
'home_address',
'federal_identifier',
'tel_num'
]

dicti = dict()
for j in pi_list:
        dicti[str(j)]=0

for i in data_list:
    for j in pi_list:
        if str(j) in str(i):
            dicti[j] = dicti[j]+1

for j in dicti:
     if dicti[j] > 0 :
       print(j, dicti[j])
# Out:
# address 4
# address

# %%
# pi_list = [
# 'account_name',
# 'password_reset_secret',
# 'ip_address',
# 'credit_card_num',
# 'first_name',
# 'last_name',
# 'date_of_birth',
# 'email_address',
# 'mac_address',
# 'account_identifier',
# 'serial_num',
# 'customer_account_num',
# 'home_address',
# 'federal_identifier',
# 'tel_num'
# ]

# pi_list = [
# 'first_name',
# 'last_name',
# 'email_address',
# 'email',
# 'mail',
# 'address',
# 'tel_num',
# 'tel_num_work',
# ]

# for i in data_list:
#     for j in pi_list:
#                 if str(j) in str(i):
#                         print()
